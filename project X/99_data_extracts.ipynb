# %% [markdown]
# # Bronze data-extractor
#
# Extracts the data config files

# %%
BRONZE_SCHEMA = "bronze"
CONTRACT_TABLE = ["cfg_schema_drift_definition"
, "cfg_data_domain"
, "cfg_schema_definition_candidate"
, "cfg_schema_contract_column"
, "cfg_archived_schema_live"
, "cfg_bronze_schema_live"
, "cfg_gold_lineage_mapping"
, "cfg_referential_exception"
, "cfg_silver_export_load"
, "cfg_silver_load_control"
, "cfg_table_load_metric"
]
OVERWRITE_FILES = True
# Out:
# StatementMeta(, 52a7a5f7-a208-420f-86d5-6777c1d4b40f, 3, Finished, Available, Finished, False)

# %%
# %run ./99_common_library
# Out:
# StatementMeta(, 52a7a5f7-a208-420f-86d5-6777c1d4b40f, 8, Finished, Available, Finished, True)

# %%
from datetime import datetime, timezone
from uuid import uuid4

RUN_ID = str(uuid4())
PROFILED_AT = datetime.now(timezone.utc)
# Out:
# StatementMeta(, 52a7a5f7-a208-420f-86d5-6777c1d4b40f, 9, Finished, Available, Finished, False)

# %%
for _table in CONTRACT_TABLE:
    full_name = f"monitoring.{_table}"
    _CSV_PATH = f"/lakehouse/default/Files/cfg_files/{_table}.csv"
    if not spark.catalog.tableExists(full_name):
        raise RuntimeError(f"Schema contract table does not exist: {full_name}")
    df= spark.table(full_name)
    pdf = df.toPandas()
    
    pdf.to_csv(_CSV_PATH, index=False)
    print(f"table exported: {full_name} written to {_CSV_PATH}")
# Out:
# StatementMeta(, 52a7a5f7-a208-420f-86d5-6777c1d4b40f, 19, Finished, Available, Finished, False)
# table exported: monitoring.cfg_schema_drift_definition written to /lakehouse/default/Files/cfg_files/cfg_schema_drift_definition.csv
# table exported: monitoring.cfg_data_domain written to /lakehouse/default/Files/cfg_files/cfg_data_domain.csv
# table exported: monitoring.cfg_schema_definition_candidate written to /lakehouse/default/Files/cfg_files/cfg_schema_definition_candidate.csv
# table exported: monitoring.cfg_schema_contract_column written to /lakehouse/default/Files/cfg_files/cfg_schema_contract_column.csv
# table exported: monitoring.cfg_archived_schema_live written to /lakehouse/default/Files/cfg_files/cfg_archived_schema_live.csv
# table exported: monitoring.cfg_bronze_schema_live written to /lakehouse/default/Files/cfg_files/cfg_bronze_schema_live.csv
# table exported: monitoring.cfg_gold_lineage_mapping written to /lakehouse/default/Files/cfg_files/cfg_gold_lineage_mapping.csv
# table exported: monitoring.cfg_referential_exception written to /lakehouse/default/Files/cfg_files/cfg_referential_exception.csv
# table exported: monitoring.cfg_silver_export_load written to /lakehouse/default/Files/cfg_files/cfg_silver_export_load.csv
# table exported: monitoring.cfg_silver_load_control written to /lakehouse/default/Files/cfg_files/cfg_silver_load_control.csv
# table exported: monitoring.cfg_table_load_metric written to /lakehouse/default/Files/cfg_files/cfg_table_load_metric.csv
